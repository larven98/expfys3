# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
operando_redlaser_df = pd.read_csv('groupe3b_CV_0.1mV_s_red_laser_C01.txt',header=None)
operando_redlaser_df = operando_redlaser_df[0].str.split(expand=True)
operando_redlaser_df.columns = operando_redlaser_df.iloc[0]
operando_redlaser_df = operando_redlaser_df.drop(0)
operando_redlaser_df.drop(['number'],axis=1)
operando_redlaser_df = operando_redlaser_df.astype(float)

operando_blue1_df = pd.read_csv('group_b_operando_2_blue_15s_x10_25p_C01.txt',header=None)
operando_blue1_df = operando_blue1_df[0].str.split(expand=True)
operando_blue1_df.columns = operando_blue1_df.iloc[0]
operando_blue1_df = operando_blue1_df.drop(0)
operando_blue1_df.drop(['number'],axis=1)
operando_blue1_df = operando_blue1_df.astype(float)

# %%
fig,ax=plt.subplots(figsize=(15,10))

ax.plot(operando_redlaser_df['time/s']/3600,operando_redlaser_df['<I>/mA']/np.max(np.abs(operando_redlaser_df['<I>/mA'])),
        c='#22b49a',label='Current (normalised)')
ax.plot(operando_redlaser_df['time/s']/3600,operando_redlaser_df['Ewe/V']/np.max(np.abs(operando_redlaser_df['Ewe/V'])),
        c='#954cde',label='Potential (normalised)')
ax.set_xlabel('$t$ [h]',fontsize=14)
ax.set_ylabel('$I, V$ ([mA], [V])',fontsize=14)
ax.set_title('$I(t), V(t)$, operando measurement I (red laser)',fontsize=18,pad=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig('time_current_potential_red.png')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))

ax.plot(operando_blue1_df['time/s']/3600,operando_blue1_df['<I>/mA']/np.max(np.abs(operando_blue1_df['<I>/mA'])),
        c='#22b49a',label='Current (normalised)')
ax.plot(operando_blue1_df['time/s']/3600,operando_blue1_df['Ewe/V']/np.max(np.abs(operando_blue1_df['Ewe/V'])),
        c='#954cde',label='Potential (normalised)')
ax.set_xlabel('$t$ [h]',fontsize=14)
ax.set_ylabel('$I, V$ ([mA], [V])',fontsize=14)
ax.set_title('$I(t), V(t)$, operando measurement I (blue laser)',fontsize=18,pad=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig('time_current_potential_blue.png')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))
scat = ax.scatter(operando_redlaser_df['Ewe/V'],operando_redlaser_df['<I>/mA'],c=operando_redlaser_df['time/s']/3600, cmap='rainbow',s=0.5)
cbar = fig.colorbar(scat,ax=ax)
cbar.set_label('Time, $t$ [h]',fontsize=14)
ax.set_xlabel('Potential, $V$ [V]',fontsize=14)
ax.set_ylabel('Current, $I$ [mA]',fontsize=14)
ax.set_title('$I(V)$, operando measurement I (red laser)',fontsize=18,pad=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig('pot_current_red.png')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))
scat = ax.scatter(operando_blue1_df['Ewe/V'],operando_blue1_df['<I>/mA'],c=operando_blue1_df['time/s']/3600, cmap='rainbow',s=0.5)
cbar = fig.colorbar(scat,ax=ax)
cbar.set_label('Time, $t$ [h]',fontsize=14)
ax.set_xlabel('Potential, $V$ [V]',fontsize=14)
ax.set_ylabel('Current, $I$ [mA]',fontsize=14)
ax.set_title('$I(V)$, operando measurement II (blue laser)',fontsize=18,pad=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig('pot_current_blue.png')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))
scat = ax.scatter(operando_redlaser_df[operando_redlaser_df['cycle']==1.0]['Ewe/V'],
                    operando_redlaser_df[operando_redlaser_df['cycle'] == 1.0]['<I>/mA'],
                    c = operando_redlaser_df[operando_redlaser_df['cycle']==1.0]['time/s']/3600, cmap='rainbow',s=0.5)
cbar = fig.colorbar(scat,ax=ax)
cbar.set_label('Time, $t$ [h]',fontsize=14)
ax.set_xlabel('Potential, $V$ [V]',fontsize=14)
ax.set_ylabel('Current, $I$ [mA]',fontsize=14)
ax.set_title('$I(V)$, operando measurement I (red laser, 1st cycle)',fontsize=18,pad=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig('pot_current_red_cycle1.png')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))
scat = ax.scatter(operando_blue1_df[operando_blue1_df['cycle']==3.0]['Ewe/V'],
                    operando_blue1_df[operando_blue1_df['cycle']==3.0]['<I>/mA'],
                    c = operando_blue1_df[operando_blue1_df['cycle']==3.0]['time/s']/3600, cmap='rainbow',s=0.5)
cbar = fig.colorbar(scat,ax=ax)
cbar.set_label('Time, $t$ [h]',fontsize=14)
ax.set_xlabel('Potential, $V$ [V]',fontsize=14)
ax.set_ylabel('Current, $I$ [mA]',fontsize=14)
ax.set_title('$I(V)$, operando measurement II (blue laser, final cycle)',fontsize=18,pad=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig('pot_current_blue_finalcycle.png')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))
scat1 = ax.plot(operando_redlaser_df[operando_redlaser_df['cycle']==1.0]['Ewe/V'],
                    operando_redlaser_df[operando_redlaser_df['cycle'] == 1.0]['<I>/mA'],c='#22b49a', label= 'Red laser, first cycle')
scat2 = ax.plot(operando_blue1_df[operando_blue1_df['cycle']==3.0]['Ewe/V'],
                    operando_blue1_df[operando_blue1_df['cycle']==3.0]['<I>/mA'],c='#954cde',label='Blue laser, final cycle')

ax.set_xlabel('Potential, $V$ [V]',fontsize=14)
ax.set_ylabel('Current, $I$ [mA]',fontsize=14)
ax.set_title('$I(V)$, first vs last operando cycle',fontsize=18,pad=12)
ax.legend(fontsize=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.savefig('pot_current_comparison.png')
plt.show()

# %%
charge_red = np.array(operando_redlaser_df['time/s'] * operando_redlaser_df['<I>/mA'])
acc_charge = []
charge = 0
for i,val in enumerate(charge_red):
    charge += val * 1e-3
    acc_charge.append(charge)
operando_redlaser_df.insert(4,'acc_charge',acc_charge)

charge_blue = operando_blue1_df['time/s'] * operando_blue1_df['<I>/mA']
acc_charge_blue = []
charge_b = 0
for i,val in enumerate(charge_blue):
    charge_b += val * 1e-3
    acc_charge_blue.append(charge_b)

operando_blue1_df.insert(4,'acc_charge',acc_charge_blue)

# %%
fig,ax=plt.subplots(figsize=(10,6.7))
scat = ax.scatter(operando_blue1_df['Ewe/V'],operando_blue1_df['acc_charge'],c=operando_blue1_df['time/s'], cmap='rainbow',s=0.5)
cbar = fig.colorbar(scat,ax=ax)
cbar.set_label('Time [s]',fontsize=14)
ax.set_xlabel('Potential, $V$ [V]',fontsize=14)
ax.set_ylabel('Charge, $Q$',fontsize=14)
# ax.set_title('$I(V)$, operando measurement I (blue laser)',fontsize=18,pad=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,6.7))
scat = ax.scatter(operando_redlaser_df['Ewe/V'],operando_redlaser_df['acc_charge'],c=operando_redlaser_df['time/s'], cmap='rainbow',s=0.5)
cbar = fig.colorbar(scat,ax=ax)
cbar.set_label('Time [s]',fontsize=14)
ax.set_xlabel('Potential, $V$ [V]',fontsize=14)
ax.set_ylabel('Charge, $Q$',fontsize=14)
# ax.set_title('$I(V)$, operando measurement I (blue laser)',fontsize=18,pad=12)
plt.tight_layout()
plt.subplots_adjust(top=0.8)
plt.show()
